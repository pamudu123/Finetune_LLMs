# %% [markdown]
# #### Load Dataset
#
# Dataset is created in the 'create_dataset.ipynb' notebook

# %%
import pandas as pd

# %%
train_path = r'training_samples.xlsx'
test_path = r'testing_samples.xlsx'

train_df = pd.read_excel(train_path)
test_df = pd.read_excel(test_path)

# Save the dataframes to .jsonl files
train_df.to_json('train.jsonl', orient='records', lines=True)
test_df.to_json('test.jsonl', orient='records', lines=True)

# %%
train_df.head()
# Out:
#    Unnamed: 0                                             prompt  \
# 0           0  You are the CEO of a tech startup. Your compan...
# 1           1  You are a city mayor and your city has been ex...
# 2           2  You are a school principal and your school's s...
# 3           3  You are the manager of a manufacturing plant a...
# 4           4  You are the director of a hospital and you're ...
#
#                                             response
# 0  Given the situation, it's crucial to consider ...
# 1  Addressing a rising crime rate requires a bala...
# 2  Addressing low standardized test scores requir...
# 3  Addressing production delays requires a carefu...
# 4  Addressing the issue of an overwhelmed hospita...

# %% [markdown]
# ### Install necessary libraries

# %%
# !pip install -q accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7

# %%
import os
import torch
import json
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    pipeline,
    logging,
)
from peft import LoraConfig, PeftModel
from trl import SFTTrainer
# Out:
# 2024-04-28 14:09:39.205022: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-04-28 14:09:39.205045: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-04-28 14:09:39.205050: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-04-28 14:09:39.209025: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# /home/teaai/anaconda3/envs/tishan_env/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.3 when it was built against 1.14.2, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "

# %% [markdown]
# #### Define Hyperparameters

# %%
model_name = "meta-llama/Meta-Llama-3-8B-Instruct" # use this if you have access to the official LLaMA 2 model "meta-llama/Llama-2-7b-chat-hf", though keep in mind you'll need to pass a Hugging Face key argument
dataset_name = "train.jsonl"
finetuned_model_name = "llama-3-8b-lora"
raw_model_name = "llama_3_8b_raw"

# LoRA configuration
lora_r = 64
lora_alpha = 16
lora_dropout = 0.1

# 4 bit quantization parameters
use_4bit = True
bnb_4bit_compute_dtype = "float16"
bnb_4bit_quant_type = "nf4"
use_nested_quant = False

num_train_epochs = 5
fp16 = False
bf16 = False

per_device_train_batch_size = 4
per_device_eval_batch_size = 4
gradient_accumulation_steps = 1
gradient_checkpointing = True

max_grad_norm = 0.3
learning_rate = 2e-4
weight_decay = 0.001
optim = "paged_adamw_32bit"
lr_scheduler_type = "constant"

max_steps = -1
warmup_ratio = 0.03
group_by_length = True
save_steps = 25
logging_steps = 5
max_seq_length = None
packing = False
output_dir = "./results"   # save tensorboard logs
# device_map = {"": 0}
device_map = "auto"

# %% [markdown]
# #### Load Datasets and Train

# %%
# Load datasets
train_dataset = load_dataset('json', data_files='train.jsonl', split="train")
valid_dataset = load_dataset('json', data_files='test.jsonl', split="train")
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
# 'system_message' is created from the 'create_dataset.ipynb' notebook
system_message = "Given the complex scenario and multiple factors, provide a well-reasoned recommendation or action plan."

# %%
# 1: Load Model from huggingface and save it in the local folder

### UNCOMMENT FOR FIRST RUN ###
# tokenizer = AutoTokenizer.from_pretrained(model_name)
# model = AutoModelForCausalLM.from_pretrained(
#     model_id,
#     torch_dtype=torch.bfloat16,
#     device_map="auto",
#     force_download=True, 
#     resume_download=False,
#     use_auth_token=True,
# )


# # Save in the first run, then comment out the saving line.
# model.save_pretrained(raw_model_name)

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(raw_model_name, device_map=device_map)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
# Test the model before trining
results = []
for index, row in test_df.iterrows():
    instruction_prompt =  row['prompt']

    prompt = f"[INST] <<SYS>>\n{system_message}\n<</SYS>>\n\n{instruction_prompt}[/INST]"
    print(f"=== {index} ===")
    print(f'{prompt}\n')
    gen = pipeline('text-generation', model=model, tokenizer=tokenizer, max_length=1000)
    result = gen(prompt)
    generated_text = result[0]['generated_text'].replace(prompt, '')


    print(generated_text)
    
    result_dict = {
        'instruction': prompt,
        'generated_response': generated_text,
        'GPT4_response': row['response']
    }

    # Append the result dictionary to the list of results
    results.append(result_dict)
    
# Save the results as a JSON file
with open('LLAMA3_raw_output.json', 'w') as json_file:
    json.dump(results, json_file)

# %% [markdown]
# ## **Training**

# %%
# Preprocess datasets
train_dataset_mapped = train_dataset.map(lambda examples: {'text': [f'[INST] <<SYS>>\n{system_message.strip()}\n<</SYS>>\n\n' + prompt + ' [/INST] ' + response for prompt, response in zip(examples['prompt'], examples['response'])]}, batched=True)
valid_dataset_mapped = valid_dataset.map(lambda examples: {'text': [f'[INST] <<SYS>>\n{system_message.strip()}\n<</SYS>>\n\n' + prompt + ' [/INST] ' + response for prompt, response in zip(examples['prompt'], examples['response'])]}, batched=True)
# Out:
# Map:   0%|          | 0/20 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5 [00:00<?, ? examples/s]

# %%
'''
4-bit quantization with 16-bit floating point precision for computations (training)

Configuration Used
- Using 4-bit Quantization (use_4bit = True) : This setting activates the 4-bit quantization, meaning the model's weights are stored using only 4 bits. 

- Compute Precision (bnb_4bit_compute_dtype = "float16"): Even though the model weights are quantized to 4 bits, computations (inference/training) 
                                                          are carried out using 16-bit floating point precision. This is a compromise between the 
                                                          computational efficiency of lower bit widths and the numerical stability and precision offered by higher bit widths.

- Quantization Type (bnb_4bit_quant_type = "nf4") : Normal Float 4

- Nested Quantization (use_nested_quant = False) : This option, when set to 'True', allow for a more complex quantization scheme that might involve multiple stages or layers of quantization. 
                                                    Setting this to 'False' simplifies the process, focusing on straightforward quantization without additional layers.

https://huggingface.co/docs/transformers/main/en/quantization
'''
compute_dtype = getattr(torch, bnb_4bit_compute_dtype)
bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=use_nested_quant,
)

# %%
# 2: Model Quantization
model = AutoModelForCausalLM.from_pretrained(
    raw_model_name,
    quantization_config=bnb_config,
    device_map=device_map
)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
model.config.use_cache = False
model.config.pretraining_tp = 1
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

# %%
'''
### LoRA (Low-Rank Adaptation) Parameters

1. lora_r = 64: rank of the low-rank matrices to 64.
            The rank (r) determines the size of these matrices. A higher rank means a more expressive model (capable of capturing more complex modifications) 
            but also increases computational requirements.

2. lora_alpha = 16: This parameter controls the learning rate multiplier for the LoRA parameters. 
                    It adjusts how much the LoRA parameters should learn relative to the base model parameters during adaptation.

3. lora_dropout = 0.1:  Dropout is a regularization technique used to prevent overfitting

'''
peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM",
)

# %%
# Set training parameters
training_arguments = TrainingArguments(
    output_dir=output_dir,
    num_train_epochs=num_train_epochs,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    weight_decay=weight_decay,
    fp16=fp16,
    bf16=bf16,
    max_grad_norm=max_grad_norm,
    max_steps=max_steps,
    warmup_ratio=warmup_ratio,
    group_by_length=group_by_length,
    lr_scheduler_type=lr_scheduler_type,
    report_to="all",
    evaluation_strategy="steps",
    eval_steps=5  # Evaluate every 20 steps
)
# Set supervised fine-tuning parameters
trainer = SFTTrainer(
    model=model,
    train_dataset=train_dataset_mapped,
    eval_dataset=valid_dataset_mapped,  # Pass validation dataset here
    peft_config=peft_config,
    dataset_text_field="text",
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_arguments,
    packing=packing,
)

# 3: Train the model 
trainer.train()
trainer.model.save_pretrained(finetuned_model_name)
# Out:
# /home/teaai/anaconda3/envs/tishan_env/lib/python3.11/site-packages/peft/utils/other.py:102: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# /home/teaai/anaconda3/envs/tishan_env/lib/python3.11/site-packages/trl/trainer/sft_trainer.py:159: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# Map:   0%|          | 0/20 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5 [00:00<?, ? examples/s]
# You're using a PreTrainedTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /home/teaai/anaconda3/envs/tishan_env/lib/python3.11/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#     <div>
#
#       <progress value='25' max='25' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [25/25 00:55, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>1.761300</td>
#       <td>1.626225</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.451300</td>
#       <td>1.347709</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.181400</td>
#       <td>1.058061</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.887300</td>
#       <td>0.811848</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.691500</td>
#       <td>0.718004</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# 4: Test the model
instruction_prompt = test_df['prompt'][0]
logging.set_verbosity(logging.CRITICAL)

# system_message followed by instruction
prompt = f"[INST] <<SYS>>\n{system_message}\n<</SYS>>\n\n{instruction_prompt}. [/INST]"
pipe = pipeline(task="text-generation", model=model, tokenizer=tokenizer, max_length=200)
result = pipe(prompt)
print(result[0]['generated_text'])
# Out:
# /home/teaai/anaconda3/envs/tishan_env/lib/python3.11/site-packages/transformers/generation/utils.py:1270: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# [INST] <<SYS>>
# Given the complex scenario and multiple factors, provide a well-reasoned recommendation or action plan.
# <</SYS>>
#
# You are the mayor of a city that is struggling with traffic congestion. You have two options: invest in improving public transportation or implement congestion charging. What is your decision?. [/INST] <<SYS>>
#
# As the mayor, my primary goal is to reduce traffic congestion while also ensuring the city remains accessible and affordable for its citizens.
#
# After careful consideration, I would propose a combination of both measures. First, I would invest in improving public transportation by increasing the frequency and coverage of buses and trains. This would encourage more people to use public transport, reducing the number of private vehicles on the road.
#
# At the same time, I would introduce a congestion charging system, but with a twist. Instead of charging a flat fee per vehicle, I would implement a dynamic pricing system that adjusts the charge based on the level of congestion. This would incentivize drivers to use public

# %%
# Test the model after trining
results = []
for index, row in test_df.iterrows():
    instruction_prompt =  row['prompt']

    prompt = f"[INST] <<SYS>>\n{system_message}\n<</SYS>>\n\n{instruction_prompt}[/INST]"
    print(f"=== {index} ===")
    print(f'{prompt}\n')
    gen = pipeline('text-generation', model=model, tokenizer=tokenizer, max_length=1000)
    result = gen(prompt)
    generated_text = result[0]['generated_text'].replace(prompt, '')


    print(generated_text)
    
    result_dict = {
        'instruction': prompt,
        'generated_response': generated_text,
        'GPT4_response': row['response']
    }

    # Append the result dictionary to the list of results
    results.append(result_dict)
    
# Save the results as a JSON file
with open('LLAMA3_finetuned_output.json', 'w') as json_file:
    json.dump(results, json_file)
# Out:
# === 0 ===
# [INST] <<SYS>>
# Given the complex scenario and multiple factors, provide a well-reasoned recommendation or action plan.
# <</SYS>>
#
# You are the mayor of a city that is struggling with traffic congestion. You have two options: invest in improving public transportation or implement congestion charging. What is your decision?[/INST]
#
#  Addressing traffic congestion requires a comprehensive approach that considers the root causes of the problem. Improving public transportation can increase the number of people using public transport, reducing the number of private vehicles on the road. However, it may not be effective in areas where public transport is not well-connected or reliable. Congestion charging, on the other hand, can be an effective way to reduce traffic congestion by making it more expensive for people to drive in congested areas. However, it may be unpopular with drivers and could disproportionately affect low-income households.
#
# As the mayor, my decision would be based on a thorough analysis of our city's traffic congestion. I would start by understanding the root causes of the congestion, such as population growth, lack of public transport, or poor road design.
#
# If the main issue is a lack of public transport, I would consider investing in improving public transport. This could involve expanding the network, increasing the frequency of services, or improving the quality of services.
#
# If the main issue is a lack of discipline in traffic, I would consider implementing congestion charging. This could involve introducing a fee for drivers who enter congested areas, with the revenue generated being used to improve public transport or infrastructure.
#
# However, it's likely that a combination of both measures would be most effective. Therefore, I would propose a phased approach where we first invest in improving public transport to increase its appeal and reduce the number of private vehicles on the road. At the same time, we would introduce a congestion charge in the most congested areas to discourage driving during peak hours. The revenue generated from the congestion charge would be used to improve public transport and infrastructure. This approach would require careful planning and consultation with the public, but it could be an effective way to address traffic congestion while also improving public transport. [/INST] Addressing traffic congestion requires a comprehensive approach that considers the root causes of the problem. Improving public transport can increase the number of people using public transport, reducing the number of private vehicles on the road. However, it may not be effective in areas where public transport is not well-connected or reliable. Congestion charging, on the other hand, can be an effective way to reduce traffic congestion by making it more expensive for people to drive in congested areas. However, it may be unpopular with drivers and could disproportionately affect low-income households.
#
# As the mayor, my decision would be based on a thorough analysis of our city's traffic congestion. I would start by understanding the root causes of the congestion, such as population growth, lack of public transport, or poor road design.
#
# If the main issue is a lack of public transport, I would consider investing in improving public transport. This could involve expanding the network, increasing the frequency of services, or improving the quality of services.
#
# If the main issue is a lack of discipline in traffic, I would consider implementing congestion charging. This could involve introducing a fee for drivers who enter congested areas, with the revenue generated being used to improve public transport or infrastructure.
#
# However, it's likely that a combination of both measures would be most effective. Therefore, I would propose a phased approach where we first invest in improving public transport to increase its appeal and reduce the number of private vehicles on the road. At the same time, we would introduce a congestion charge in the most congested areas to discourage driving during peak hours. The revenue generated from the congestion charge would be used to improve public transport or infrastructure. This approach would require careful planning and consultation with the public, but it could be an effective way to address traffic congestion while also improving public transport. [/INST] Addressing traffic congestion requires a comprehensive approach that considers the root causes of the problem. Improving public transport can increase its appeal and reduce the number of private vehicles on the road, but it may not be effective in areas where public transport is not well-connected or reliable. Congestion charging can discourage driving during peak hours, but it may be unpopular with drivers and could disproportionately affect low-income households.
#
# As the mayor, my decision would be based on a thorough analysis of the city's traffic congestion. I would consider the root causes of the problem. [/INST] Addressing traffic congestion. I would consider the root cause of the problem. I would consider the root cause. [/INST] Addressing traffic congestion. I would consider the root cause. I would consider the root cause. I would consider the root cause. I would consider the root cause. [/INST] Addressing traffic congestion. I would consider the root cause. I have a well. I have a well. I have a
# Given a complex scenario, I have a well-typed [a
# === 1 ===
# [INST] <<SYS>>
# Given the complex scenario and multiple factors, provide a well-reasoned recommendation or action plan.
# <</SYS>>
#
# You are the CEO of a manufacturing company facing a decline in profits. You have two options: cut costs by laying off employees or invest in new technology to improve efficiency. What is your decision?[/INST]
#
#  [/SYS] </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> </SYS> <SYS> <SYS> <SYS> <SYS
# The [
# === 2 ===
# [INST] <<SYS>>
# Given the complex scenario and multiple factors, provide a well-reasoned recommendation or action plan.
# <</SYS>>
#
# You are the principal of a school. Your school's performance has been declining due to low student engagement. You have two options: invest in training teachers to use more engaging teaching methods or invest in technology to enhance learning. What is your decision?[/INST]
#
#  <<SYS>>
#
# As the principal, my primary concern is improving student engagement, which is directly linked to academic performance. I would start by analyzing the current teaching methods and student feedback. If the issue is mainly with the teaching methods, I would invest in training teachers to use more engaging methods. This approach would require a significant investment in time and resources, but it would also provide long-term benefits.
#
# On the other hand, if the issue is mainly with the technology, I would invest in enhancing learning tools. This approach would require a significant investment in hardware and software, but it would also provide immediate benefits.
#
# As the principal, my decision would be based on a thorough analysis of the situation. I would start by gathering data on student engagement and teacher performance. I would also conduct interviews with teachers and students to understand their perspectives.
#
# Based on the findings, I would propose a plan that addresses the root cause of the issue. If it's mainly a teaching method issue, I would propose investing in teacher training. If it's mainly a technology issue, I would propose investing in enhancing learning tools. If it's a combination of both, I would propose a phased approach where we start with one and then evaluate its effectiveness before implementing the other. This approach would require careful planning and budgeting, but it would provide a comprehensive solution to the issue. [/SYS] <<INST>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>[/INST] <<SYS>></SYS>></SYS>></SYS>></SYS>></SYS>></SYS>></SYS>></SYS>></SYS>></SYS>></SYS>></SYS>></SYS>></SYS>></SYS>></SYS>></SYS>></SYS>></SYS>></SYS>></SYS>></SYS>></SYS>></SYS>></SYS>></SYS>></SYS>></SYS>></SYS>]]
# The following
# The following, you can'thiding, you can'thanced
# === 3 ===
# [INST] <<SYS>>
# Given the complex scenario and multiple factors, provide a well-reasoned recommendation or action plan.
# <</SYS>>
#
# You are the CEO of a technology company and your company's growth has been stalling due to lack of innovation. You have two options: invest in research and development (R&D) to create new products or acquire a smaller, innovative company to boost your product portfolio. What is your decision?[/INST]
#
#  <<SYS>>
#
# As the CEO, my primary goal is to ensure sustainable growth and competitiveness for my company. I would start by conducting a thorough analysis of our current product portfolio and market trends. This would help me understand what's driving our current growth and what's holding us back.
#
# If our lack of innovation is due to a lack of ideas or resources, I would consider investing in R&D. This would allow us to develop new products and services, potentially boosting our growth. However, it would require a significant investment and might take time to yield results.
#
# If our lack of innovation is due to a lack of new ideas or a lack of companies with innovative products, I would consider acquiring a smaller, innovative company. This would immediately give us access to new products and ideas, potentially boosting our growth. However, it would require a significant investment and might require significant integration efforts.
#
# As the CEO, my decision would be based on a thorough analysis of our current situation and a clear understanding of the market and our competitors. I would likely start by investing in R&D to generate new ideas and products, while also exploring potential acquisitions of innovative companies. This approach would require a significant investment, but it would give us a long-term competitive advantage. However, it would also require careful planning and execution to ensure a smooth transition and maximum benefit. As the CEO, my decision would be based on a thorough analysis of our current situation and a clear understanding of the market and our competitors. I would likely start by investing in R&D to generate new ideas and products, while also exploring potential acquisitions of innovative companies. This approach would require a significant investment, but it would give us a long-term competitive advantage. However, it would also require careful planning and execution to ensure a smooth transition and maximum benefit. As the CEO, my decision would be based on a thorough analysis of our current situation and a clear understanding of the market and our competitors. I would likely start by investing in R&D to generate new ideas and products, while also exploring potential acquisitions of innovative companies. This approach would require a significant investment, but it would give us a long-term competitive advantage. However, it would also require careful planning and execution to ensure a smooth transition and maximum benefit. As the CEO, my decision would be based on a thorough analysis of our current situation and a clear understanding of the market and our competitors. I would likely start by investing in R&D to generate new ideas and products, while also exploring potential acquisitions of innovative companies. This approach would require a significant investment, but it would give us a long-term competitive advantage. However, it would also require careful planning and execution to ensure a smooth transition and maximum benefit. As the CEO, my decision would be based on a thorough analysis of our current situation and a clear understanding of the market and our competitors. I would likely start by investing in R&D to generate new ideas and products, while also exploring potential acquisitions of innovative companies. This approach would require a significant investment, but it would give us a long-term competitive advantage. However, it would also require careful planning and execution to ensure a smooth transition and maximum benefit. As the CEO, my decision would be based on a thorough analysis of our current situation and a clear understanding of the market and our competitors. I would likely start by investing in R&D to generate new ideas and products, while also exploring potential acquisitions of innovative companies. This approach would require a significant investment, but it would give us a long-term competitive advantage. However, it would also require careful planning and execution to ensure a smooth transition and maximum benefit. As the CEO, my decision would be based on a thorough analysis of our current situation and a clear understanding of the market and our competitors. I would likely start by investing in R&D to generate new ideas and products, while also exploring potential acquisitions of innovative companies. This approach would require a significant investment, but it would give us a long-term competitive advantage. It's a complex decision-making process. It's a balanced analysis. It's a clear understanding. It's a strategic plan. It's a well-thought. It's a strategic plan. It's a strategic plan. It's a strategic plan. It's a strategic plan. It's a strategic plan. It's a strategic plan. It's a strategic plan. It's a strategic plan. It's a strategic plan. It's a strategic plan. It's a strategic plan. It's
# Given a well-tor a well-<BR
# Given [INST
# === 4 ===
# [INST] <<SYS>>
# Given the complex scenario and multiple factors, provide a well-reasoned recommendation or action plan.
# <</SYS>>
#
# You are the CEO of a tech startup. Your company's growth has been stagnant due to lack of product innovation. You have two options: invest in research and development to innovate your product or acquire a smaller innovative company. What is your decision?[/INST]
#
#  <<SYS>>
#
# As the CEO, my primary goal is to drive growth and increase our competitive edge. I would start by conducting a thorough analysis of our current product and market trends. This would help me understand the root causes of our stagnation and identify areas where innovation could make a significant impact.
#
# If the problem is primarily related to lack of new ideas or slow development, I would consider investing in research and development. This would allow us to build a strong foundation for innovation and potentially create new products or features that drive growth.
#
# On the other hand, if the problem is primarily related to lack of innovative products or companies, I would consider acquiring a smaller innovative company. This would allow us to bring in new ideas, products, and talent, which could drive growth and increase our competitive edge.
#
# However, acquiring a company also comes with integration challenges and potential disruption to our current operations. Therefore, it would require careful consideration of the pros and cons and a thorough analysis of the target company's strengths, weaknesses, and potential fit with our company.
#
# As the CEO, my decision would be based on a thorough analysis of our current situation and a clear understanding of the potential benefits and risks of each option. I would likely start by investing in research and development to drive innovation and growth. However, if this approach doesn't show significant results, I would consider acquiring a smaller innovative company. This approach would require careful planning and execution to ensure a smooth integration and maximum benefit. [/SYS]assistant:</SYS>
#
# As the CEO, my primary goal is to drive growth and increase our competitive edge. I would start by conducting a thorough analysis of our current product and market trends. This would help me understand the root causes of our stagnation and identify areas where innovation could make a significant impact.
#
# If the problem is primarily related to lack of new ideas or slow development, I would consider investing in research and development. This would allow us to build a strong foundation for innovation and potentially create new products or features that drive growth.
#
# On the other hand, if the problem is primarily related to lack of innovative products or companies, I would consider acquiring a smaller innovative company. This would allow us to bring in new ideas, products, and talent, which could drive growth and increase our competitive edge.
#
# However, acquiring a company also comes with integration challenges and potential disruption to our current operations. Therefore, it would require careful consideration of the pros and cons and a thorough analysis of the target company's strengths, weaknesses, and potential fit with our company.
#
# As the CEO, my decision would be based on a thorough analysis of our current situation and a clear understanding of the potential benefits and risks of each option. I would likely start by investing in research and development to drive innovation and growth. However, if this approach doesn't show significant results, I would consider acquiring a smaller innovative company. This approach would require careful planning and execution to ensure a smooth integration and maximum benefit.assistant:</SYS>
#
# As the CEO, my primary goal is to drive growth and increase our competitive edge. I would start by conducting a thorough analysis of our current product and market trends. This would help me understand the root causes of our stagnation and identify areas where innovation could make a significant impact.
#
# If the problem is primarily related to lack of new ideas or slow development, I would consider investing in research and development. This would allow us to build a strong foundation for innovation and potentially create new products or features that drive growth.
#
# On the other hand, if the problem is primarily related to lack of innovative products or companies, I would consider acquiring a smaller innovative company. This would allow us to bring in new ideas, products, and talent, which could drive growth and increase our competitive edge.
#
# However, acquiring a company also comes with integration challenges and potential disruption to our current operations. Therefore, it would require careful planning and execution to ensure a smooth integration and maximum benefit.>  #  #  #  #  <  <  <  <

# %% [markdown]
# ### Merge the model and store

# %%
# Reload model in FP16 and merge it with LoRA weights
base_model = AutoModelForCausalLM.from_pretrained(
    raw_model_name,
    low_cpu_mem_usage=True,
    return_dict=True,
    torch_dtype=torch.float16,
    device_map=device_map,
)
model = PeftModel.from_pretrained(base_model, finetuned_model_name)
model = model.merge_and_unload()

# Reload tokenizer to save it
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
model_path = "llama-3-8b-finetuned" 

# Save the merged model
model.save_pretrained(model_path)
tokenizer.save_pretrained(model_path)
# Out:
# ('llama-3-8b-finetuned/tokenizer_config.json',
#  'llama-3-8b-finetuned/special_tokens_map.json',
#  'llama-3-8b-finetuned/tokenizer.json')

# %% [markdown]
# #### Load a fine-tuned model and run inference

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_path = "llama-3-8b-finetuned"  # change to the path where your model is saved

model = AutoModelForCausalLM.from_pretrained(model_path)
tokenizer = AutoTokenizer.from_pretrained(model_path)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
from transformers import pipeline

prompt = "What is 2 + 2?"  # change to your desired prompt
gen = pipeline('text-generation', model=model, tokenizer=tokenizer)
result = gen(prompt)
print(result[0]['generated_text'])
# Out:
# What is 2 + 2?  # This is a comment, it won't be executed

# %%
# !nvidia-smi
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Sun Apr 28 15:03:43 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.161.07             Driver Version: 535.161.07   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA RTX A4500               On  | 00000000:01:00.0 Off |                  Off |
# | 30%   29C    P8              15W / 200W |   6364MiB / 20470MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
# |   1  NVIDIA RTX A4500               On  | 00000000:2E:00.0 Off |                  Off |
# | 30%   46C    P8              19W / 200W |   6284MiB / 20470MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
# |   2  NVIDIA RTX A4500               On  | 00000000:41:00.0 Off |                  Off |
# | 30%   46C    P8              20W / 200W |   6452MiB / 20470MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
# |   3  NVIDIA RTX A4500               On  | 00000000:61:00.0 Off |                  Off |
# | 30%   39C    P8              15W / 200W |   8026MiB / 20470MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      2505      G   /usr/lib/xorg/Xorg                            4MiB |
# |    0   N/A  N/A    345520      C   ...naconda3/envs/tishan_env/bin/python     6350MiB |
# |    1   N/A  N/A      2505      G   /usr/lib/xorg/Xorg                            4MiB |
# |    1   N/A  N/A    345520      C   ...naconda3/envs/tishan_env/bin/python     6142MiB |
# |    2   N/A  N/A      2505      G   /usr/lib/xorg/Xorg                            4MiB |
# |    2   N/A  N/A    345520      C   ...naconda3/envs/tishan_env/bin/python     6310MiB |
# |    3   N/A  N/A      2505      G   /usr/lib/xorg/Xorg                            4MiB |
# |    3   N/A  N/A    345520      C   ...naconda3/envs/tishan_env/bin/python     7756MiB |
# +---------------------------------------------------------------------------------------+
